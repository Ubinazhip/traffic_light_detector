# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Akatsuki/darknet/darknet')

# %%
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:967:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !chmod +x ./darknet detector train /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/voc-bosch.data /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/yolov3-tiny-bosch.cfg /content/drive/MyDrive/Akatsuki/darknet/darknet53.conv.74 -gpus 0
# Out:
# chmod: invalid mode: ‘-gpus’
# Try 'chmod --help' for more information.

# %%
# !./darknet detector train /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/voc-bosch.data /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/yolov3-tiny-bosch.cfg /content/drive/MyDrive/Akatsuki/darknet/darknet53.conv.74 -gpus 0
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 145897: 1.441571, 1.718871 avg, 0.001000 rate, 0.013729 seconds, 145897 images
# Loaded: 0.032927 seconds
# Region 16 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000141, .5R: -nan, .75R: -nan,  count: 0
# 145898: 0.034738, 1.550457 avg, 0.001000 rate, 0.012900 seconds, 145898 images
# Loaded: 0.037502 seconds
# Region 16 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000038, .5R: -nan, .75R: -nan,  count: 0
# 145899: 0.001203, 1.395532 avg, 0.001000 rate, 0.015245 seconds, 145899 images
# Loaded: 0.047118 seconds
# Region 16 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive

# %%
# !./darknet detector test /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/voc-bosch.data /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/yolov3-tiny-bosch.cfg /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/backup3/yolov3-tiny-bosch_80000.weights /content/drive/MyDrive/Akatsuki/darknet/data/video2_frame530.jpg -dont_show
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...
