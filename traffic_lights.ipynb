# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Akatsuki/darknet/darknet')

# %%
# !chmod +x ./darknet detector train /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/voc-bosch.data /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/yolov3.cfg /content/drive/MyDrive/Akatsuki/darknet/darknet53.conv.74 gpus 0
# Out:
# chmod: cannot access 'detector': No such file or directory
# chmod: cannot access 'train': No such file or directory
# chmod: cannot access 'gpus': No such file or directory
# chmod: cannot access '0': No such file or directory

# %%
# !./darknet detector train /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/voc-bosch.data /content/drive/MyDrive/Akatsuki/darknet/traffic-lights/yolov3.cfg /content/drive/MyDrive/Akatsuki/darknet/darknet53.conv.74 -gpus 0
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Region 106 Avg IOU: 0.187335, Class: 0.412502, Obj: 0.261148, No Obj: 0.000214, .5R: 0.250000, .75R: 0.000000,  count: 8
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.493234, Class: 0.922108, Obj: 0.437937, No Obj: 0.000329, .5R: 0.571429, .75R: 0.000000,  count: 7
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000007, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.230089, Class: 0.525663, Obj: 0.173447, No Obj: 0.000219, .5R: 0.200000, .75R: 0.000000,  count: 10
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan,  count: 0
# ...
